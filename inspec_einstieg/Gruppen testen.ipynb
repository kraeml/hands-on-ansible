# %% [markdown]
# # Inspec Gruppen testen

# %%
pwd
# Out:
# /home/vagrant/rdf/ais/hands-on-ansible/inspec_einstieg

# %%
inspec --version
# Out:
# WARN: Unresolved specs during Gem::Specification.reset:
#       winrm-fs (~> 1.0)
#       thor (~> 0.19)
# WARN: Clearing out unresolved specs.
# Please report a bug if this causes problems.
# 1.50.1

# %%
inspec check example
# Out:
# WARN: Unresolved specs during Gem::Specification.reset:
#       winrm-fs (~> 1.0)
#       thor (~> 0.19)
# WARN: Clearing out unresolved specs.
# Please report a bug if this causes problems.
# Location:    example
# Profile:     example
# Controls:    6
# Timestamp:   2018-01-24T11:09:46+00:00
# Valid:       true
#
# No errors or warnings

# %%
tree example
# Out:
# example
# ├── controls
# │   ├── example.rb
# │   └── familie.rb
# ├── inspec.lock
# ├── inspec.yml
# ├── libraries
# └── README.md
#
# 2 directories, 5 files

# %%
sudo lxc-ls --fancy
# Out:
# The configuration file contains legacy configuration keys.
# Please update your configuration file!
# NAME       STATE   AUTOSTART GROUPS IPV4 IPV6
# ais-bashy  STOPPED 0         -      -    -
# db         STOPPED 0         -      -    -
# playbooks  STOPPED 0         -      -    -
# user-bashy STOPPED 0         -      -    -
# web1       STOPPED 0         -      -    -
# web2       STOPPED 0         -      -    -

# %%
sudo lxc-start -n user-bashy
sudo lxc-start -n db
sudo lxc-start -n web1
sudo lxc-start -n web2
sudo lxc-start -n ais-bashy
sudo lxc-start -n playbooks
# Out:
# The configuration file contains legacy configuration keys.
# Please update your configuration file!

# %%
sudo lxc-ls --fancy
# Out:
# The configuration file contains legacy configuration keys.
# Please update your configuration file!
# NAME       STATE   AUTOSTART GROUPS IPV4       IPV6
# ais-bashy  RUNNING 0         -      10.0.3.85  -
# db         RUNNING 0         -      10.0.3.84  -
# playbooks  RUNNING 0         -      10.0.3.103 -
# user-bashy RUNNING 0         -      10.0.3.3   -
# web1       RUNNING 0         -      10.0.3.197 -
# web2       RUNNING 0         -      10.0.3.70  -

# %%
cat example/controls/example.rb
# Out:
# # encoding: utf-8
# # copyright: 2017, The Authors
#
# title 'sample section'
#
# gruppen = [ 'familie', 'erwachsene', 'finanzen', 'rezepte', 'kinder' ]
# benutzer = [ 'vater', 'mutter', 'tochter', 'sohn', 'kindermaedchen', 'gast' ]
# verzeichnisse = [ 'familienfotos', 'gruselfilme', 'finanzen', 'kochrezepte', 'zeichenfilme' ]
#
# control 'Verzeichnisse-1.0' do
#   impact 1.0
#   title 'Test Verzeichnisse'
#   desc 'Verzeichnisse einfache Anwesenheit'
#   verzeichnisse.each do|v|
#     describe file('/var/'+v) do
#       it { should be_directory }
#     end
#   end
# end
#
# control 'Benutzer-1.0' do
#   impact 1.0
#   title 'Test Gruppen'
#   desc 'Benutzer sind da'
#   benutzer.each do|b|
#     describe user(b) do
#       it { should exist }
#     end
#   end
# end
#
# control 'Gruppen-1.0' do
#   impact 1.0
#   title 'Test Gruppen'
#   desc 'Gruppen sind da'
#   gruppen.each do|g|
#     describe group(g) do
#       it { should exist }
#     end
#   end
# end
#
# ...

# %%
inspec exec example -t ssh://ubuntu:ubuntu@10.0.3.3
# Out:
# WARN: Unresolved specs during Gem::Specification.reset:
#       winrm-fs (~> 1.0)
#       thor (~> 0.19)
# WARN: Clearing out unresolved specs.
# Please report a bug if this causes problems.
#
# Profile: InSpec Profile (example)
# Version: 0.1.0
# Target:  ssh://ubuntu@10.0.3.3:22
#
#   ×  User-1.0: Teste User (25 failed)
#      ×  User vater should exist
#      expected User vater to exist
#      ×  User vater groups should be in "vater", "erwachsene", "familie", and "finanzen"
#      expected `` to be in the list: `["vater", "erwachsene", "familie", "finanzen"]`
#      ×  User vater group should eq "vater"
#
#      expected: "vater"
#           got: nil
#
#      (compared using ==)
#
#      ×  User vater home should eq "/home/vater"
#
#      expected: "/home/vater"
#           got: nil
#
#      (compared using ==)
#
#      ×  User vater shell should eq "/bin/csh"
#
#      expected: "/bin/csh"
#           got: nil
#
#      (compared using ==)
#
#      ×  User mutter should exist
# ...

# %%
cd ../02-playbooks/00-simple-playbook-examples/user-playbook

# %%
pwd
# Out:
# /home/vagrant/rdf/ais/hands-on-ansible/02-playbooks/00-simple-playbook-examples/user-playbook

# %%
ls
# Out:
# ansible.cfg  hosts  user.retry	user.yml

# %%
cat hosts
# Out:
# [ais-bashy]
# 10.0.3.85  ansible_user=root
#
# [db]
# 10.0.3.84  ansible_user=root
#
# [playbooks]
# 10.0.3.103 ansible_user=root
#
# [web1]
# 10.0.3.197 ansible_user=root
#
# [web2]
# 10.0.3.70  ansible_user=root
#
# [user]
# 10.0.3.3   ansible_user=ubuntu

# %%
ansible-playbook user.yml
# Out:
#  ____________
# < PLAY [all] >
#  ------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||
#
#  ________________________
# < TASK [Gathering Facts] >
#  ------------------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||
#
# ok: [10.0.3.85]
# ok: [10.0.3.70]
# ok: [10.0.3.84]
# ok: [10.0.3.103]
# fatal: [10.0.3.3]: UNREACHABLE! => {"changed": false, "msg": "Failed to connect to the host via ssh: Permission denied (publickey,password).\r\n", "unreachable": true}
# ok: [10.0.3.197]
#  ______________________________
# < TASK [Erstellen der Gruppen] >
#  ------------------------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||
#
# ok: [10.0.3.70] => (item=erwachsene)
# ok: [10.0.3.197] => (item=erwachsene)
# ...

# %%
inspec exec example -t ssh://ubuntu:ubuntu@10.0.3.85
# Out:
# WARN: Unresolved specs during Gem::Specification.reset:
#       winrm-fs (~> 1.0)
#       thor (~> 0.19)
# WARN: Clearing out unresolved specs.
# Please report a bug if this causes problems.
# Could not fetch inspec profile in "example".
# : 1

# %%
cd ../../../inspec_einstieg

# %%
inspec exec example -t ssh://ubuntu:ubuntu@10.0.3.85
# Out:
# WARN: Unresolved specs during Gem::Specification.reset:
#       winrm-fs (~> 1.0)
#       thor (~> 0.19)
# WARN: Clearing out unresolved specs.
# Please report a bug if this causes problems.
#
# Profile: InSpec Profile (example)
# Version: 0.1.0
# Target:  ssh://ubuntu@10.0.3.85:22
#
#   ✔  User-1.0: Teste User
#      ✔  User vater should exist
#      ✔  User vater groups should be in "vater", "erwachsene", "familie", and "finanzen"
#      ✔  User vater group should eq "vater"
#      ✔  User vater home should eq "/home/vater"
#      ✔  User vater shell should eq "/bin/csh"
#      ✔  User mutter should exist
#      ✔  User mutter groups should be in "mutter", "erwachsene", "familie", "rezepte", and "finanzen"
#      ✔  User mutter home should eq "/home/mutter"
#      ✔  User mutter shell should eq "/bin/bash"
#      ✔  User tochter should exist
#      ✔  User tochter groups should be in "tochter", "familie", and "kinder"
#      ✔  User tochter home should eq "/home/tochter"
# ...
